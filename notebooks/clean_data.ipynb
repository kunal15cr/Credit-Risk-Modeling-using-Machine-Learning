# %%
import numpy as np
import pandas as pd
import warnings
import os
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
from scipy.stats import chi2_contingency
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, precision_recall_fscore_support

# %% [markdown]
# # Internal Data

# %%
Internal_path = Path.cwd().parent / "data"/ "interim" / "case_study1.xlsx"

# %% [markdown]
# # Cibil External data

# %%
External_path = Path.cwd().parent / "data"/  "external" / "case_study2.xlsx"

# %%
df1 = pd.read_excel(External_path)
df2 = pd.read_excel(Internal_path)

# %% [markdown]
#  # Internal Data clean up

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51336 entries, 0 to 51335
# Data columns (total 62 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   PROSPECTID                    51336 non-null  int64
#  1   time_since_recent_payment     51336 non-null  int64
#  2   time_since_first_deliquency   51336 non-null  int64
#  3   time_since_recent_deliquency  51336 non-null  int64
#  4   num_times_delinquent          51336 non-null  int64
#  5   max_delinquency_level         51336 non-null  int64
#  6   max_recent_level_of_deliq     51336 non-null  int64
#  7   num_deliq_6mts                51336 non-null  int64
#  8   num_deliq_12mts               51336 non-null  int64
#  9   num_deliq_6_12mts             51336 non-null  int64
#  10  max_deliq_6mts                51336 non-null  int64
#  11  max_deliq_12mts               51336 non-null  int64
#  12  num_times_30p_dpd             51336 non-null  int64
#  13  num_times_60p_dpd             51336 non-null  int64
#  14  num_std                       51336 non-null  int64
#  15  num_std_6mts                  51336 non-null  int64
#  16  num_std_12mts                 51336 non-null  int64
#  17  num_sub                       51336 non-null  int64
#  18  num_sub_6mts                  51336 non-null  int64
#  19  num_sub_12mts                 51336 non-null  int64
#  20  num_dbt                       51336 non-null  int64
#  21  num_dbt_6mts                  51336 non-null  int64
#  22  num_dbt_12mts                 51336 non-null  int64
#  23  num_lss                       51336 non-null  int64
#  24  num_lss_6mts                  51336 non-null  int64
#  25  num_lss_12mts                 51336 non-null  int64
#  26  recent_level_of_deliq         51336 non-null  int64
#  27  tot_enq                       51336 non-null  int64
#  28  CC_enq                        51336 non-null  int64
#  29  CC_enq_L6m                    51336 non-null  int64
#  30  CC_enq_L12m                   51336 non-null  int64
#  31  PL_enq                        51336 non-null  int64
#  32  PL_enq_L6m                    51336 non-null  int64
#  33  PL_enq_L12m                   51336 non-null  int64
#  34  time_since_recent_enq         51336 non-null  int64
#  35  enq_L12m                      51336 non-null  int64
#  36  enq_L6m                       51336 non-null  int64
#  37  enq_L3m                       51336 non-null  int64
#  38  MARITALSTATUS                 51336 non-null  object
#  39  EDUCATION                     51336 non-null  object
#  40  AGE                           51336 non-null  int64
#  41  GENDER                        51336 non-null  object
#  42  NETMONTHLYINCOME              51336 non-null  int64
#  43  Time_With_Curr_Empr           51336 non-null  int64
#  44  pct_of_active_TLs_ever        51336 non-null  float64
#  45  pct_opened_TLs_L6m_of_L12m    51336 non-null  float64
#  46  pct_currentBal_all_TL         51336 non-null  float64
#  47  CC_utilization                51336 non-null  float64
#  48  CC_Flag                       51336 non-null  int64
#  49  PL_utilization                51336 non-null  float64
#  50  PL_Flag                       51336 non-null  int64
#  51  pct_PL_enq_L6m_of_L12m        51336 non-null  float64
#  52  pct_CC_enq_L6m_of_L12m        51336 non-null  float64
#  53  pct_PL_enq_L6m_of_ever        51336 non-null  float64
#  54  pct_CC_enq_L6m_of_ever        51336 non-null  float64
#  55  max_unsec_exposure_inPct      51336 non-null  float64
#  56  HL_Flag                       51336 non-null  int64
#  57  GL_Flag                       51336 non-null  int64
#  58  last_prod_enq2                51336 non-null  object
#  59  first_prod_enq2               51336 non-null  object
#  60  Credit_Score                  51336 non-null  int64
#  61  Approved_Flag                 51336 non-null  object
# dtypes: float64(10), int64(46), object(6)
# memory usage: 24.3+ MB

# %%
def null_value(df):
    columns_remove_list = []
    for i in df.columns:
        if df.loc[df[i] == -99999].shape[0] > 10000:
            columns_remove_list.append(i)
    return columns_remove_list

# %%
null_value(df1)
# Out:
# ['time_since_first_deliquency',
#  'time_since_recent_deliquency',
#  'max_delinquency_level',
#  'max_deliq_6mts',
#  'max_deliq_12mts',
#  'CC_utilization',
#  'PL_utilization',
#  'max_unsec_exposure_inPct']

# %%
def clean_data(df):
    return (
        df
        .drop(null_value(df),axis=1)
        .replace(-99999, np.nan)  # Replace -99999 with NaN
        .dropna()
    )#.isna().sum()

# %%
clean_data(df1)
# Out:
#        PROSPECTID  time_since_recent_payment  num_times_delinquent  \
# 0               1                      549.0                    11
# 1               2                       47.0                     0
# 2               3                      302.0                     9
# 4               5                      583.0                     0
# 5               6                      245.0                    14
# ...           ...                        ...                   ...
# 51331       51332                       15.0                     2
# 51332       51333                       57.0                     0
# 51333       51334                       32.0                     0
# 51334       51335                       58.0                     0
# 51335       51336                       74.0                     0
#
#        max_recent_level_of_deliq  num_deliq_6mts  num_deliq_12mts  \
# 0                             29               0                0
# 1                              0               0                0
# 2                             25               1                9
# 4                              0               0                0
# 5                            270               0                0
# ...                          ...             ...              ...
# 51331                         24               0                0
# 51332                          0               0                0
# 51333                          0               0                0
# 51334                          0               0                0
# 51335                          0               0                0
#
#        num_deliq_6_12mts  num_times_30p_dpd  num_times_60p_dpd  num_std  ...  \
# 0                      0                  0                  0       21  ...
# 1                      0                  0                  0        0  ...
# 2                      8                  0                  0       10  ...
# 4                      0                  0                  0       53  ...
# 5                      0                 13                 11        5  ...
# ...                  ...                ...                ...      ...  ...
# 51331                  0                  0                  0        0  ...
# 51332                  0                  0                  0        6  ...
# 51333                  0                  0                  0        0  ...
# 51334                  0                  0                  0        0  ...
# 51335                  0                  0                  0       18  ...
#
#        pct_PL_enq_L6m_of_L12m  pct_CC_enq_L6m_of_L12m  pct_PL_enq_L6m_of_ever  \
# 0                         0.0                     0.0                   0.000
# 1                         0.0                     0.0                   0.000
# 2                         0.0                     0.0                   0.000
# 4                         0.0                     0.0                   0.000
# 5                         1.0                     0.0                   0.429
# ...                       ...                     ...                     ...
# 51331                     0.0                     0.0                   0.000
# 51332                     0.0                     0.0                   0.000
# 51333                     1.0                     0.0                   1.000
# 51334                     0.0                     0.0                   0.000
# 51335                     0.0                     0.0                   0.000
#
#        pct_CC_enq_L6m_of_ever  HL_Flag  GL_Flag  last_prod_enq2  \
# 0                         0.0        1        0              PL
# 1                         0.0        0        0    ConsumerLoan
# 2                         0.0        1        0    ConsumerLoan
# 4                         0.0        0        0              AL
# 5                         0.0        1        0    ConsumerLoan
# ...                       ...      ...      ...             ...
# 51331                     0.0        0        0    ConsumerLoan
# 51332                     0.0        0        0          others
# 51333                     0.0        0        0    ConsumerLoan
# 51334                     0.0        0        0    ConsumerLoan
# 51335                     0.0        0        0          others
#
#        first_prod_enq2  Credit_Score  Approved_Flag
# 0                   PL           696             P2
# 1         ConsumerLoan           685             P2
# 2               others           693             P2
# 4                   AL           753             P1
# 5                   PL           668             P3
# ...                ...           ...            ...
# 51331     ConsumerLoan           650             P4
# 51332           others           702             P1
# 51333           others           661             P3
# 51334           others           686             P2
# 51335           others           681             P2
#
# [42066 rows x 54 columns]

# %%
clean_data(df2).columns
# Out:
# Index(['PROSPECTID', 'Total_TL', 'Tot_Closed_TL', 'Tot_Active_TL',
#        'Total_TL_opened_L6M', 'Tot_TL_closed_L6M', 'pct_tl_open_L6M',
#        'pct_tl_closed_L6M', 'pct_active_tl', 'pct_closed_tl',
#        'Total_TL_opened_L12M', 'Tot_TL_closed_L12M', 'pct_tl_open_L12M',
#        'pct_tl_closed_L12M', 'Tot_Missed_Pmnt', 'Auto_TL', 'CC_TL',
#        'Consumer_TL', 'Gold_TL', 'Home_TL', 'PL_TL', 'Secured_TL',
#        'Unsecured_TL', 'Other_TL', 'Age_Oldest_TL', 'Age_Newest_TL'],
#       dtype='object')

# %%
for i in clean_data(df1).columns:
    if i in  clean_data(df2).columns:
        print(i)
# Out:
# PROSPECTID

# %%
df = pd.merge(clean_data(df1),clean_data(df2),how='inner',left_on= ["PROSPECTID"],right_on=['PROSPECTID'])

# %%
df
# Out:
#        PROSPECTID  time_since_recent_payment  num_times_delinquent  \
# 0               1                      549.0                    11
# 1               2                       47.0                     0
# 2               3                      302.0                     9
# 3               5                      583.0                     0
# 4               6                      245.0                    14
# ...           ...                        ...                   ...
# 42059       51332                       15.0                     2
# 42060       51333                       57.0                     0
# 42061       51334                       32.0                     0
# 42062       51335                       58.0                     0
# 42063       51336                       74.0                     0
#
#        max_recent_level_of_deliq  num_deliq_6mts  num_deliq_12mts  \
# 0                             29               0                0
# 1                              0               0                0
# 2                             25               1                9
# 3                              0               0                0
# 4                            270               0                0
# ...                          ...             ...              ...
# 42059                         24               0                0
# 42060                          0               0                0
# 42061                          0               0                0
# 42062                          0               0                0
# 42063                          0               0                0
#
#        num_deliq_6_12mts  num_times_30p_dpd  num_times_60p_dpd  num_std  ...  \
# 0                      0                  0                  0       21  ...
# 1                      0                  0                  0        0  ...
# 2                      8                  0                  0       10  ...
# 3                      0                  0                  0       53  ...
# 4                      0                 13                 11        5  ...
# ...                  ...                ...                ...      ...  ...
# 42059                  0                  0                  0        0  ...
# 42060                  0                  0                  0        6  ...
# 42061                  0                  0                  0        0  ...
# 42062                  0                  0                  0        0  ...
# 42063                  0                  0                  0       18  ...
#
#        CC_TL  Consumer_TL  Gold_TL  Home_TL  PL_TL  Secured_TL  Unsecured_TL  \
# 0          0            0        1        0      4           1             4
# 1          0            1        0        0      0           0             1
# 2          0            6        1        0      0           2             6
# 3          0            0        0        0      0           3             0
# 4          0            0        2        0      0           6             0
# ...      ...          ...      ...      ...    ...         ...           ...
# 42059      0            2        0        0      0           0             3
# 42060      0            2        0        0      0           2             2
# 42061      0            2        0        0      0           0             2
# 42062      0            2        0        0      0           0             2
# 42063      0            0        0        0      0           1             0
#
#        Other_TL  Age_Oldest_TL  Age_Newest_TL
# 0             0           72.0           18.0
# 1             0            7.0            7.0
# 2             0           47.0            2.0
# 3             2          131.0           32.0
# 4             0          150.0           17.0
# ...         ...            ...            ...
# 42059         1           24.0            5.0
# 42060         0           74.0            7.0
# 42061         0            9.0            5.0
# 42062         0           15.0            8.0
# 42063         0           20.0           20.0
#
# [42064 rows x 79 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42064 entries, 0 to 42063
# Data columns (total 79 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PROSPECTID                  42064 non-null  int64
#  1   time_since_recent_payment   42064 non-null  float64
#  2   num_times_delinquent        42064 non-null  int64
#  3   max_recent_level_of_deliq   42064 non-null  int64
#  4   num_deliq_6mts              42064 non-null  int64
#  5   num_deliq_12mts             42064 non-null  int64
#  6   num_deliq_6_12mts           42064 non-null  int64
#  7   num_times_30p_dpd           42064 non-null  int64
#  8   num_times_60p_dpd           42064 non-null  int64
#  9   num_std                     42064 non-null  int64
#  10  num_std_6mts                42064 non-null  int64
#  11  num_std_12mts               42064 non-null  int64
#  12  num_sub                     42064 non-null  int64
#  13  num_sub_6mts                42064 non-null  int64
#  14  num_sub_12mts               42064 non-null  int64
#  15  num_dbt                     42064 non-null  int64
#  16  num_dbt_6mts                42064 non-null  int64
#  17  num_dbt_12mts               42064 non-null  int64
#  18  num_lss                     42064 non-null  int64
#  19  num_lss_6mts                42064 non-null  int64
#  20  num_lss_12mts               42064 non-null  int64
#  21  recent_level_of_deliq       42064 non-null  int64
#  22  tot_enq                     42064 non-null  float64
#  23  CC_enq                      42064 non-null  float64
#  24  CC_enq_L6m                  42064 non-null  float64
#  25  CC_enq_L12m                 42064 non-null  float64
#  26  PL_enq                      42064 non-null  float64
#  27  PL_enq_L6m                  42064 non-null  float64
#  28  PL_enq_L12m                 42064 non-null  float64
#  29  time_since_recent_enq       42064 non-null  float64
#  30  enq_L12m                    42064 non-null  float64
#  31  enq_L6m                     42064 non-null  float64
#  32  enq_L3m                     42064 non-null  float64
#  33  MARITALSTATUS               42064 non-null  object
#  34  EDUCATION                   42064 non-null  object
#  35  AGE                         42064 non-null  int64
#  36  GENDER                      42064 non-null  object
#  37  NETMONTHLYINCOME            42064 non-null  int64
#  38  Time_With_Curr_Empr         42064 non-null  int64
#  39  pct_of_active_TLs_ever      42064 non-null  float64
#  40  pct_opened_TLs_L6m_of_L12m  42064 non-null  float64
#  41  pct_currentBal_all_TL       42064 non-null  float64
#  42  CC_Flag                     42064 non-null  int64
#  43  PL_Flag                     42064 non-null  int64
#  44  pct_PL_enq_L6m_of_L12m      42064 non-null  float64
#  45  pct_CC_enq_L6m_of_L12m      42064 non-null  float64
#  46  pct_PL_enq_L6m_of_ever      42064 non-null  float64
#  47  pct_CC_enq_L6m_of_ever      42064 non-null  float64
#  48  HL_Flag                     42064 non-null  int64
#  49  GL_Flag                     42064 non-null  int64
#  50  last_prod_enq2              42064 non-null  object
#  51  first_prod_enq2             42064 non-null  object
#  52  Credit_Score                42064 non-null  int64
#  53  Approved_Flag               42064 non-null  object
#  54  Total_TL                    42064 non-null  int64
#  55  Tot_Closed_TL               42064 non-null  int64
#  56  Tot_Active_TL               42064 non-null  int64
#  57  Total_TL_opened_L6M         42064 non-null  int64
#  58  Tot_TL_closed_L6M           42064 non-null  int64
#  59  pct_tl_open_L6M             42064 non-null  float64
#  60  pct_tl_closed_L6M           42064 non-null  float64
#  61  pct_active_tl               42064 non-null  float64
#  62  pct_closed_tl               42064 non-null  float64
#  63  Total_TL_opened_L12M        42064 non-null  int64
#  64  Tot_TL_closed_L12M          42064 non-null  int64
#  65  pct_tl_open_L12M            42064 non-null  float64
#  66  pct_tl_closed_L12M          42064 non-null  float64
#  67  Tot_Missed_Pmnt             42064 non-null  int64
#  68  Auto_TL                     42064 non-null  int64
#  69  CC_TL                       42064 non-null  int64
#  70  Consumer_TL                 42064 non-null  int64
#  71  Gold_TL                     42064 non-null  int64
#  72  Home_TL                     42064 non-null  int64
#  73  PL_TL                       42064 non-null  int64
#  74  Secured_TL                  42064 non-null  int64
#  75  Unsecured_TL                42064 non-null  int64
#  76  Other_TL                    42064 non-null  int64
#  77  Age_Oldest_TL               42064 non-null  float64
#  78  Age_Newest_TL               42064 non-null  float64
# dtypes: float64(27), int64(46), object(6)
# memory usage: 25.4+ MB
